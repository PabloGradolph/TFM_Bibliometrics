# %% [markdown]
# ## Agrupación de IPs por sus palabras clave

# %% [markdown]
# Paso 1: Cargar el dataset

# %%
import pandas as pd

df = pd.read_csv("Keywords/author_keyword_matrix.csv", index_col=0)

# Mostrar resumen
print("✅ Dataset generado con forma:", df.shape)
print("🔢 Palabras clave totales:", len(df.columns))
print("👥 Autores con keywords:", len(df))
# Out:
# ✅ Dataset generado con forma: (29, 3304)
# 🔢 Palabras clave totales: 3304
# 👥 Autores con keywords: 29

# %% [markdown]
# Paso 2: Preprocesamiento (normalización y reducción PCA)

# %%
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA

X = df.values
X_normalized = Normalizer().fit_transform(X)

# %% [markdown]
# Paso 3: Clustering con Jerárquico

# %%
# === Configuraciones de preprocesamiento y clustering ===
pca_dims = [2, 5, 10, 20]
k_values = list(range(2, 16))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Evaluar KMeans para k entre 2 y 15
results = []

for n_dim in pca_dims:
    X_reduced = PCA(n_components=n_dim).fit_transform(X_normalized)

    Z = linkage(X_reduced, method='ward')

    for k in k_values:
        try:
            labels = fcluster(Z, t=k, criterion='maxclust')

            silhouette = silhouette_score(X_reduced, labels)
            ch_score = calinski_harabasz_score(X_reduced, labels)
            db_score = davies_bouldin_score(X_reduced, labels)

            results.append({
                "PCA_dims": n_dim,
                "k": k,
                "Silhouette": silhouette,
                "Calinski-Harabasz": ch_score,
                "Davies-Bouldin": db_score,
                "Labels": labels
            })

        except Exception as e:
            results.append({
                "PCA_dims": n_dim,
                "k": k,
                "Silhouette": np.nan,
                "Calinski-Harabasz": np.nan,
                "Davies-Bouldin": np.nan,
                "Error": str(e),
                "Labels": []
            })

df_results = pd.DataFrame(results).dropna(subset=["Silhouette"])
print("✅ Resultados de clustering jerárquico generados:", df_results.shape)
print("🔍 Resultados de clustering:", df_results)
# Out:
# ✅ Resultados de clustering jerárquico generados: (56, 6)
# 🔍 Resultados de clustering:     PCA_dims   k  Silhouette  Calinski-Harabasz  Davies-Bouldin  \
# 0          2   2    0.459077          24.075598        0.829327
# 1          2   3    0.603951          47.785584        0.572078
# 2          2   4    0.599318          56.605998        0.487559
# 3          2   5    0.599945          71.222957        0.529714
# 4          2   6    0.642105          84.221907        0.438492
# 5          2   7    0.634311          86.273717        0.437759
# 6          2   8    0.580648          92.765277        0.503060
# 7          2   9    0.566287         111.460180        0.479250
# 8          2  10    0.629297         156.119631        0.400745
# 9          2  11    0.655075         177.591135        0.382490
# 10         2  12    0.617444         195.759797        0.316123
# 11         2  13    0.572545         224.660211        0.394481
# 12         2  14    0.550017         254.865092        0.334028
# 13         2  15    0.532384         303.632720        0.265568
# 14         5   2    0.302145           8.192903        0.822909
# 15         5   3    0.363678           9.011403        1.187494
# 16         5   4    0.449827          11.217604        1.007773
# 17         5   5    0.523383          14.869402        0.812446
# 18         5   6    0.617852          24.788540        0.501585
# 19         5   7    0.695744          49.318958        0.371641
# 20         5   8    0.687952          63.186646        0.397076
# 21         5   9    0.730927          76.600869        0.350667
# 22         5  10    0.706944          86.419881        0.411055
# 23         5  11    0.675472         104.307619        0.426671
# 24         5  12    0.635763         125.877181        0.334393
# 25         5  13    0.622620         151.165427        0.229796
# 26         5  14    0.544099         183.172510        0.307002
# 27         5  15    0.520253         197.815391        0.359803
# 28        10   2    0.146457           4.734915        1.223537
# 29        10   3    0.214961           4.758277        1.654737
# 30        10   4    0.271184           5.189184        1.564685
# 31        10   5    0.343060           5.676611        1.325710
# 32        10   6    0.412243           6.366163        1.128746
# 33        10   7    0.495189           7.562215        0.965923
# 34        10   8    0.591115           9.749139        0.740954
# 35        10   9    0.627769          12.451010        0.751535
# 36        10  10    0.686256          18.627789        0.609485
# 37        10  11    0.744748          35.321157        0.401490
# 38        10  12    0.699309          40.131667        0.297732
# 39        10  13    0.694152          49.456953        0.300939
# 40        10  14    0.654914          55.689423        0.348330
# 41        10  15    0.633804          62.773847        0.306829
# 42        20   2    0.072992           3.090801        1.824962
# 43        20   3    0.108060           2.938506        2.247008
# 44        20   4    0.152842           2.987151        2.132258
# 45        20   5    0.211891           3.008994        1.868926
# 46        20   6    0.273190           3.092633        1.709071
# 47        20   7    0.329435           3.207589        1.491449
# 48        20   8    0.413161           3.371533        1.297325
# 49        20   9    0.427967           3.474412        1.303368
# 50        20  10    0.435359           3.557346        1.307248
# 51        20  11    0.436775           3.637225        1.252832
# 52        20  12    0.437644           3.773113        1.000809
# 53        20  13    0.439673           3.966283        0.902784
# 54        20  14    0.441608           4.271151        0.805601
# 55        20  15    0.442451           4.731504        0.673698
#
#                                                Labels
# 0   [2, 1, 1, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 1, 1, ...
# 1   [3, 1, 1, 3, 2, 3, 1, 3, 3, 3, 1, 2, 2, 1, 1, ...
# 2   [4, 1, 1, 3, 2, 3, 1, 4, 4, 4, 1, 2, 2, 1, 1, ...
# 3   [5, 2, 2, 4, 3, 4, 2, 5, 5, 5, 2, 3, 3, 1, 1, ...
# 4   [6, 2, 2, 5, 4, 5, 3, 6, 6, 6, 3, 4, 4, 1, 1, ...
# 5   [7, 2, 2, 6, 5, 6, 3, 7, 7, 7, 3, 5, 5, 1, 1, ...
# 6   [8, 2, 2, 7, 6, 7, 3, 8, 8, 8, 3, 6, 6, 1, 1, ...
# 7   [9, 2, 2, 7, 6, 7, 3, 9, 8, 8, 3, 6, 6, 1, 1, ...
# 8   [10, 2, 2, 8, 6, 8, 3, 10, 9, 9, 3, 6, 6, 1, 1...
# 9   [11, 2, 2, 9, 7, 9, 3, 11, 10, 10, 3, 6, 6, 1,...
# 10  [12, 2, 2, 10, 8, 10, 3, 12, 11, 11, 3, 7, 7, ...
# 11  [13, 2, 2, 10, 8, 10, 3, 12, 11, 11, 3, 7, 7, ...
# 12  [14, 2, 2, 11, 9, 11, 3, 13, 12, 12, 4, 8, 8, ...
# 13  [15, 2, 2, 12, 10, 12, 3, 14, 13, 13, 4, 9, 9,...
# 14  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 15  [3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 2, 1, 1, ...
# 16  [4, 4, 4, 3, 2, 3, 4, 4, 4, 4, 4, 2, 2, 1, 1, ...
# 17  [5, 4, 4, 3, 2, 3, 5, 5, 5, 5, 5, 2, 2, 1, 1, ...
# 18  [6, 5, 5, 4, 3, 4, 6, 6, 6, 6, 6, 2, 2, 1, 1, ...
# 19  [7, 5, 5, 4, 3, 4, 7, 7, 6, 6, 7, 2, 2, 1, 1, ...
# 20  [7, 5, 5, 4, 3, 4, 8, 7, 6, 6, 8, 2, 2, 1, 1, ...
# 21  [8, 6, 6, 5, 3, 5, 9, 8, 7, 7, 9, 2, 2, 1, 1, ...
# 22  [9, 7, 7, 6, 4, 6, 10, 9, 8, 8, 10, 2, 2, 1, 1...
# 23  [10, 8, 8, 7, 5, 7, 11, 10, 9, 9, 11, 3, 3, 1,...
# 24  [10, 8, 8, 7, 5, 7, 11, 10, 9, 9, 12, 3, 3, 1,...
# 25  [11, 9, 9, 8, 5, 8, 12, 11, 10, 10, 13, 3, 3, ...
# 26  [12, 9, 9, 8, 5, 8, 13, 11, 10, 10, 14, 3, 3, ...
# 27  [13, 9, 9, 8, 5, 8, 14, 11, 10, 10, 15, 3, 3, ...
# 28  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 29  [3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 2, 1, 1, ...
# 30  [4, 4, 4, 3, 2, 3, 4, 4, 4, 4, 4, 2, 2, 1, 1, ...
# 31  [5, 5, 5, 3, 2, 3, 5, 5, 4, 4, 5, 2, 2, 1, 1, ...
# 32  [6, 5, 5, 3, 2, 3, 6, 6, 4, 4, 6, 2, 2, 1, 1, ...
# 33  [7, 6, 6, 4, 3, 4, 7, 7, 5, 5, 7, 2, 2, 1, 1, ...
# 34  [8, 7, 7, 5, 3, 5, 8, 8, 6, 6, 8, 2, 2, 1, 1, ...
# 35  [9, 7, 7, 5, 3, 5, 8, 8, 6, 6, 8, 2, 2, 1, 1, ...
# 36  [10, 7, 7, 5, 3, 5, 8, 8, 6, 6, 8, 2, 2, 1, 1,...
# 37  [10, 7, 7, 5, 3, 5, 8, 8, 6, 6, 8, 2, 2, 1, 1,...
# 38  [11, 7, 7, 5, 3, 5, 8, 9, 6, 6, 8, 2, 2, 1, 1,...
# 39  [12, 8, 8, 6, 4, 6, 9, 10, 7, 7, 9, 3, 3, 1, 1...
# 40  [13, 9, 9, 7, 5, 7, 10, 11, 8, 8, 10, 3, 3, 1,...
# 41  [14, 9, 9, 7, 5, 7, 10, 12, 8, 8, 11, 3, 3, 1,...
# 42  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 43  [3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 2, 1, 1, ...
# 44  [4, 4, 4, 3, 2, 3, 4, 4, 4, 4, 4, 2, 2, 1, 1, ...
# 45  [5, 4, 4, 3, 2, 3, 5, 5, 5, 5, 5, 2, 2, 1, 1, ...
# 46  [6, 4, 4, 3, 2, 3, 6, 6, 5, 5, 6, 2, 2, 1, 1, ...
# 47  [7, 5, 5, 4, 3, 4, 7, 7, 6, 6, 7, 2, 2, 1, 1, ...
# 48  [8, 6, 6, 5, 3, 5, 8, 8, 7, 7, 8, 2, 2, 1, 1, ...
# 49  [9, 6, 6, 5, 3, 5, 8, 9, 7, 7, 8, 2, 2, 1, 1, ...
# 50  [10, 6, 6, 5, 3, 5, 8, 10, 7, 7, 8, 2, 2, 1, 1...
# 51  [11, 6, 6, 5, 3, 5, 8, 11, 7, 7, 8, 2, 2, 1, 1...
# 52  [11, 6, 6, 5, 3, 5, 8, 11, 7, 7, 8, 2, 2, 1, 1...
# 53  [11, 6, 6, 5, 3, 5, 8, 11, 7, 7, 8, 2, 2, 1, 1...
# 54  [11, 6, 6, 5, 3, 5, 8, 12, 7, 7, 8, 2, 2, 1, 1...
# 55  [12, 6, 6, 5, 3, 5, 8, 13, 7, 7, 8, 2, 2, 1, 1...

# %%
## Selección por score combinado
from sklearn.preprocessing import MinMaxScaler

metrics = df_results[["Silhouette", "Calinski-Harabasz", "Davies-Bouldin"]].copy()
metrics["Davies-Bouldin"] = -metrics["Davies-Bouldin"]
scaled = pd.DataFrame(MinMaxScaler().fit_transform(metrics), columns=metrics.columns)

df_results["score_combined"] = (
    0.8 * scaled["Silhouette"] +
    0.1 * scaled["Calinski-Harabasz"] +
    0.1 * scaled["Davies-Bouldin"]
)

best_per_k = (
    df_results
    .sort_values("score_combined", ascending=False)
    .drop_duplicates(subset=["k"])
    .sort_values("k")
)

print("✅ Mejores configuraciones jerárquicas por número de clusters:")
print(best_per_k[["PCA_dims", "k", "Silhouette", "Calinski-Harabasz", "Davies-Bouldin", "score_combined"]])
# Out:
# ✅ Mejores configuraciones jerárquicas por número de clusters:
#     PCA_dims   k  Silhouette  Calinski-Harabasz  Davies-Bouldin  \
# 0          2   2    0.459077          24.075598        0.829327
# 1          2   3    0.603951          47.785584        0.572078
# 2          2   4    0.599318          56.605998        0.487559
# 3          2   5    0.599945          71.222957        0.529714
# 4          2   6    0.642105          84.221907        0.438492
# 19         5   7    0.695744          49.318958        0.371641
# 20         5   8    0.687952          63.186646        0.397076
# 21         5   9    0.730927          76.600869        0.350667
# 22         5  10    0.706944          86.419881        0.411055
# 37        10  11    0.744748          35.321157        0.401490
# 38        10  12    0.699309          40.131667        0.297732
# 39        10  13    0.694152          49.456953        0.300939
# 40        10  14    0.654914          55.689423        0.348330
# 41        10  15    0.633804          62.773847        0.306829
#
#     score_combined
# 0         0.537101
# 1         0.730270
# 2         0.731876
# 3         0.735394
# 4         0.794448
# 19        0.850033
# 20        0.844104
# 21        0.902045
# 22        0.873756
# 37        0.902258
# 38        0.854887
# 39        0.851688
# 40        0.804682
# 41        0.783956

# %% [markdown]
# Visualizamos las configuraciones

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# === Generar dendrogramas por cada configuración de PCA ===
pca_dims = [2, 5, 10, 20]
for n_dim in pca_dims:
    X_reduced = PCA(n_components=n_dim).fit_transform(X_normalized)
    
    # Linkage
    Z = linkage(X_reduced, method='ward')

    # Dendrograma
    plt.figure(figsize=(14, 6), dpi=100)
    dendrogram(
        Z,
        labels=df.index.tolist(),
        leaf_rotation=90,
        leaf_font_size=9,
        color_threshold=0  # puedes ajustar esto si quieres color automático
    )
    plt.title(f"Dendrograma (Ward linkage, PCA={n_dim}D)", fontsize=14)
    plt.xlabel("Autores")
    plt.ylabel("Distancia")
    plt.tight_layout()
    
    # Guardar cada dendrograma como imagen
    plt.savefig(f"Keywords/Hierarchical/dendrogram_pca_{n_dim}.png")
    plt.show()

# %%
## Visualización
X_2d = PCA(n_components=2).fit_transform(X_normalized)

for _, row in best_per_k.iterrows():
    labels = row["Labels"]
    coords_df = pd.DataFrame(X_2d, columns=["x", "y"])
    coords_df["author"] = df.index
    coords_df["cluster"] = labels

    plt.figure(figsize=(7, 6), dpi=100)
    sns.scatterplot(
        data=coords_df,
        x="x", y="y",
        hue="cluster",
        palette="tab10",
        s=80,
        edgecolor='k',
        alpha=0.9
    )

    for _, r in coords_df.iterrows():
        plt.text(r["x"], r["y"], r["author"], fontsize=8, alpha=0.7)

    plt.title(f"PCA={row['PCA_dims']} | k={row['k']} | Silh={row['Silhouette']:.2f}")
    plt.xticks([]); plt.yticks([])
    plt.legend(title="Cluster", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Guardamos los resultados

# %%
## Guardar resultados
cluster_records = []

for _, row in best_per_k.iterrows():
    labels = row["Labels"]
    k = row["k"]
    pca_dims = row["PCA_dims"]
    silhouette = row["Silhouette"]
    ch_score = row["Calinski-Harabasz"]
    db_score = row["Davies-Bouldin"]

    for author, cluster in zip(df.index, labels):
        cluster_records.append({
            "author": author,
            "cluster": int(cluster),
            "k": k,
            "pca_dims": pca_dims,
            "silhouette": silhouette,
            "calinski_harabasz": ch_score,
            "davies_bouldin": db_score
        })

df_clusters_export = pd.DataFrame(cluster_records)
df_clusters_export.to_csv("Keywords/Hierarchical/hierarchical_best_configs.csv", index=False)
print("✅ Resultados jerárquicos guardados en CSV.")
# Out:
# ✅ Resultados jerárquicos guardados en CSV.
