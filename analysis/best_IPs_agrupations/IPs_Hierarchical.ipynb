# %% [markdown]
# ## Agrupación de IPs por sus palabras clave

# %% [markdown]
# Paso 1: Cargar el dataset

# %%
import pandas as pd

df = pd.read_csv("Keywords/author_keyword_matrix.csv", index_col=0)

# Mostrar resumen
print("✅ Dataset generado con forma:", df.shape)
print("🔢 Palabras clave totales:", len(df.columns))
print("👥 Autores con keywords:", len(df))
# Out:
# ✅ Dataset generado con forma: (29, 3329)
# 🔢 Palabras clave totales: 3329
# 👥 Autores con keywords: 29

# %% [markdown]
# Paso 2: Preprocesamiento (normalización y reducción PCA)

# %%
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA

X = df.values
X_normalized = Normalizer().fit_transform(X)

# %% [markdown]
# Paso 3: Clustering con Jerárquico

# %%
# === Configuraciones de preprocesamiento y clustering ===
pca_dims = [2, 5, 10, 20]
k_values = list(range(2, 16))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Evaluar KMeans para k entre 2 y 15
results = []

for n_dim in pca_dims:
    X_reduced = PCA(n_components=n_dim).fit_transform(X_normalized)

    Z = linkage(X_reduced, method='ward')

    for k in k_values:
        try:
            labels = fcluster(Z, t=k, criterion='maxclust')

            silhouette = silhouette_score(X_reduced, labels)
            ch_score = calinski_harabasz_score(X_reduced, labels)
            db_score = davies_bouldin_score(X_reduced, labels)

            results.append({
                "PCA_dims": n_dim,
                "k": k,
                "Silhouette": silhouette,
                "Calinski-Harabasz": ch_score,
                "Davies-Bouldin": db_score,
                "Labels": labels
            })

        except Exception as e:
            results.append({
                "PCA_dims": n_dim,
                "k": k,
                "Silhouette": np.nan,
                "Calinski-Harabasz": np.nan,
                "Davies-Bouldin": np.nan,
                "Error": str(e),
                "Labels": []
            })

df_results = pd.DataFrame(results).dropna(subset=["Silhouette"])
print("✅ Resultados de clustering jerárquico generados:", df_results.shape)
print("🔍 Resultados de clustering:", df_results)
# Out:
# ✅ Resultados de clustering jerárquico generados: (56, 6)
# 🔍 Resultados de clustering:     PCA_dims   k  Silhouette  Calinski-Harabasz  Davies-Bouldin  \
# 0          2   2    0.472844          25.670981        0.821027
# 1          2   3    0.578545          47.611685        0.587036
# 2          2   4    0.538778          44.789039        0.539631
# 3          2   5    0.572269          50.811216        0.493005
# 4          2   6    0.600156          61.873382        0.483606
# 5          2   7    0.660430          70.878673        0.392103
# 6          2   8    0.630787          93.109994        0.458675
# 7          2   9    0.626714         108.962550        0.495996
# 8          2  10    0.622107         121.913329        0.515559
# 9          2  11    0.666728         139.471644        0.455157
# 10         2  12    0.641305         152.838998        0.374732
# 11         2  13    0.626362         180.284061        0.286989
# 12         2  14    0.597662         211.071792        0.214680
# 13         2  15    0.600536         249.748684        0.132115
# 14         5   2    0.307953           8.113747        0.812820
# 15         5   3    0.374186           8.613427        1.190816
# 16         5   4    0.398578          10.332278        1.090829
# 17         5   5    0.506226          14.039098        0.674673
# 18         5   6    0.597147          23.115926        0.494077
# 19         5   7    0.669020          38.550035        0.409549
# 20         5   8    0.707053          56.939568        0.347549
# 21         5   9    0.720819          88.273968        0.352786
# 22         5  10    0.699421         103.518020        0.368719
# 23         5  11    0.677745         118.944302        0.420612
# 24         5  12    0.642295         142.415546        0.350495
# 25         5  13    0.577281         165.920467        0.394903
# 26         5  14    0.561780         201.288579        0.298263
# 27         5  15    0.520093         213.600574        0.259238
# 28        10   2    0.145006           4.712653        1.242539
# 29        10   3    0.197985           4.707769        1.983845
# 30        10   4    0.266153           5.102997        1.578870
# 31        10   5    0.338432           5.613096        1.334583
# 32        10   6    0.408673           6.321528        1.134471
# 33        10   7    0.504882           7.541621        0.923025
# 34        10   8    0.584831           9.699247        0.744011
# 35        10   9    0.630472          12.641068        0.733206
# 36        10  10    0.687094          18.678936        0.600163
# 37        10  11    0.740425          34.124558        0.387845
# 38        10  12    0.727125          39.237303        0.384297
# 39        10  13    0.685125          45.592185        0.319230
# 40        10  14    0.650251          47.807972        0.288452
# 41        10  15    0.633451          51.774391        0.254307
# 42        20   2    0.068931           3.040006        1.841966
# 43        20   3    0.100033           2.874583        2.615951
# 44        20   4    0.141834           2.903685        2.178081
# 45        20   5    0.205848           2.935045        1.908837
# 46        20   6    0.262512           3.018188        1.722959
# 47        20   7    0.343834           3.123340        1.463122
# 48        20   8    0.397185           3.277832        1.326325
# 49        20   9    0.419460           3.371764        1.319483
# 50        20  10    0.426049           3.436958        1.322269
# 51        20  11    0.427449           3.507673        1.257608
# 52        20  12    0.428268           3.626438        1.041798
# 53        20  13    0.431308           3.797568        0.942210
# 54        20  14    0.436029           4.063514        0.857671
# 55        20  15    0.438420           4.467076        0.776238
#
#                                                Labels
# 0   [2, 1, 1, 2, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 1, ...
# 1   [3, 1, 1, 3, 3, 1, 3, 2, 3, 3, 1, 2, 2, 1, 1, ...
# 2   [3, 1, 1, 4, 4, 1, 3, 2, 4, 4, 1, 2, 2, 1, 1, ...
# 3   [4, 1, 1, 5, 5, 2, 4, 3, 5, 5, 2, 3, 3, 2, 2, ...
# 4   [5, 1, 1, 6, 6, 3, 5, 4, 6, 6, 3, 4, 4, 2, 2, ...
# 5   [5, 1, 1, 6, 6, 3, 5, 4, 7, 7, 3, 4, 4, 2, 2, ...
# 6   [6, 1, 1, 7, 7, 3, 6, 5, 8, 8, 3, 5, 5, 2, 2, ...
# 7   [7, 1, 1, 8, 8, 4, 7, 6, 9, 9, 4, 6, 6, 2, 2, ...
# 8   [8, 1, 1, 9, 9, 4, 8, 7, 10, 10, 4, 6, 6, 2, 2...
# 9   [8, 1, 1, 9, 9, 4, 8, 7, 11, 11, 4, 6, 6, 2, 2...
# 10  [9, 1, 1, 10, 10, 4, 9, 8, 12, 12, 5, 7, 7, 2,...
# 11  [10, 1, 1, 11, 11, 4, 10, 9, 13, 13, 5, 8, 8, ...
# 12  [11, 1, 1, 12, 12, 5, 11, 10, 14, 14, 6, 9, 9,...
# 13  [12, 1, 1, 13, 13, 5, 12, 10, 15, 15, 6, 9, 9,...
# 14  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 15  [3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 1, 1, ...
# 16  [4, 4, 4, 2, 2, 4, 4, 3, 4, 4, 4, 3, 3, 1, 1, ...
# 17  [5, 5, 5, 3, 3, 5, 5, 4, 5, 5, 5, 4, 4, 1, 1, ...
# 18  [6, 5, 5, 3, 3, 6, 6, 4, 6, 6, 6, 4, 4, 1, 1, ...
# 19  [7, 5, 5, 3, 3, 7, 7, 4, 6, 6, 7, 4, 4, 1, 1, ...
# 20  [8, 6, 6, 3, 3, 8, 8, 5, 7, 7, 8, 4, 4, 1, 1, ...
# 21  [8, 6, 6, 3, 3, 9, 8, 5, 7, 7, 9, 4, 4, 1, 1, ...
# 22  [9, 7, 7, 4, 4, 10, 9, 6, 8, 8, 10, 5, 5, 1, 1...
# 23  [10, 8, 8, 4, 4, 11, 10, 6, 9, 9, 11, 5, 5, 1,...
# 24  [10, 8, 8, 4, 4, 11, 10, 6, 9, 9, 12, 5, 5, 1,...
# 25  [11, 8, 8, 4, 4, 12, 10, 6, 9, 9, 13, 5, 5, 1,...
# 26  [12, 9, 9, 4, 4, 13, 11, 6, 10, 10, 14, 5, 5, ...
# 27  [13, 10, 10, 5, 5, 14, 12, 7, 11, 11, 15, 6, 6...
# 28  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 29  [2, 2, 2, 3, 3, 2, 2, 3, 2, 2, 2, 3, 3, 1, 1, ...
# 30  [2, 2, 2, 4, 4, 2, 2, 3, 2, 2, 2, 3, 3, 1, 1, ...
# 31  [3, 3, 3, 5, 5, 3, 3, 4, 2, 2, 3, 4, 4, 1, 1, ...
# 32  [4, 3, 3, 6, 6, 4, 4, 5, 2, 2, 4, 5, 5, 1, 1, ...
# 33  [4, 3, 3, 7, 7, 4, 4, 5, 2, 2, 4, 5, 5, 1, 1, ...
# 34  [4, 3, 3, 8, 8, 4, 4, 6, 2, 2, 4, 5, 5, 1, 1, ...
# 35  [5, 3, 3, 9, 9, 4, 4, 7, 2, 2, 4, 6, 6, 1, 1, ...
# 36  [6, 3, 3, 10, 10, 4, 4, 8, 2, 2, 4, 7, 7, 1, 1...
# 37  [6, 3, 3, 11, 11, 4, 4, 9, 2, 2, 4, 8, 8, 1, 1...
# 38  [7, 4, 4, 12, 12, 5, 5, 10, 3, 3, 5, 9, 9, 1, ...
# 39  [8, 4, 4, 13, 13, 5, 6, 11, 3, 3, 5, 10, 10, 1...
# 40  [8, 4, 4, 14, 14, 5, 6, 12, 3, 3, 5, 11, 11, 1...
# 41  [9, 4, 4, 15, 15, 5, 7, 13, 3, 3, 6, 12, 12, 1...
# 42  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 43  [2, 2, 2, 3, 3, 2, 2, 3, 2, 2, 2, 3, 3, 1, 1, ...
# 44  [2, 2, 2, 4, 4, 2, 2, 3, 2, 2, 2, 3, 3, 1, 1, ...
# 45  [3, 3, 3, 5, 5, 3, 3, 4, 2, 2, 3, 4, 4, 1, 1, ...
# 46  [4, 3, 3, 6, 6, 4, 4, 5, 2, 2, 4, 5, 5, 1, 1, ...
# 47  [4, 3, 3, 7, 7, 4, 4, 5, 2, 2, 4, 5, 5, 1, 1, ...
# 48  [4, 3, 3, 8, 8, 4, 4, 6, 2, 2, 4, 5, 5, 1, 1, ...
# 49  [5, 3, 3, 9, 9, 4, 5, 7, 2, 2, 4, 6, 6, 1, 1, ...
# 50  [6, 3, 3, 10, 10, 4, 6, 8, 2, 2, 4, 7, 7, 1, 1...
# 51  [7, 3, 3, 11, 11, 4, 7, 9, 2, 2, 4, 8, 8, 1, 1...
# 52  [7, 3, 3, 12, 12, 4, 7, 10, 2, 2, 4, 9, 9, 1, ...
# 53  [7, 3, 3, 13, 13, 4, 7, 11, 2, 2, 4, 10, 10, 1...
# 54  [7, 3, 3, 14, 14, 4, 8, 12, 2, 2, 4, 11, 11, 1...
# 55  [8, 3, 3, 15, 15, 4, 9, 13, 2, 2, 4, 12, 12, 1...

# %%
## Selección por score combinado
from sklearn.preprocessing import MinMaxScaler

metrics = df_results[["Silhouette", "Calinski-Harabasz", "Davies-Bouldin"]].copy()
metrics["Davies-Bouldin"] = -metrics["Davies-Bouldin"]
scaled = pd.DataFrame(MinMaxScaler().fit_transform(metrics), columns=metrics.columns)

df_results["score_combined"] = (
    0.8 * scaled["Silhouette"] +
    0.1 * scaled["Calinski-Harabasz"] +
    0.1 * scaled["Davies-Bouldin"]
)

best_per_k = (
    df_results
    .sort_values("score_combined", ascending=False)
    .drop_duplicates(subset=["k"])
    .sort_values("k")
)

print("✅ Mejores configuraciones jerárquicas por número de clusters:")
print(best_per_k[["PCA_dims", "k", "Silhouette", "Calinski-Harabasz", "Davies-Bouldin", "score_combined"]])
# Out:
# ✅ Mejores configuraciones jerárquicas por número de clusters:
#     PCA_dims   k  Silhouette  Calinski-Harabasz  Davies-Bouldin  \
# 0          2   2    0.472844          25.670981        0.821027
# 1          2   3    0.578545          47.611685        0.587036
# 2          2   4    0.538778          44.789039        0.539631
# 3          2   5    0.572269          50.811216        0.493005
# 4          2   6    0.600156          61.873382        0.483606
# 5          2   7    0.660430          70.878673        0.392103
# 20         5   8    0.707053          56.939568        0.347549
# 21         5   9    0.720819          88.273968        0.352786
# 22         5  10    0.699421         103.518020        0.368719
# 37        10  11    0.740425          34.124558        0.387845
# 38        10  12    0.727125          39.237303        0.384297
# 39        10  13    0.685125          45.592185        0.319230
# 12         2  14    0.597662         211.071792        0.214680
# 13         2  15    0.600536         249.748684        0.132115
#
#     score_combined
# 0         0.562710
# 1         0.706947
# 2         0.660335
# 3         0.704552
# 4         0.742635
# 5         0.821775
# 20        0.873468
# 21        0.902351
# 22        0.882390
# 37        0.902362
# 38        0.888732
# 39        0.843888
# 12        0.810925
# 13        0.833341

# %% [markdown]
# Visualizamos las configuraciones

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# === Generar dendrogramas por cada configuración de PCA ===
pca_dims = [2, 5, 10, 20]
for n_dim in pca_dims:
    X_reduced = PCA(n_components=n_dim).fit_transform(X_normalized)
    
    # Linkage
    Z = linkage(X_reduced, method='ward')

    # Dendrograma
    plt.figure(figsize=(14, 6), dpi=100)
    dendrogram(
        Z,
        labels=df.index.tolist(),
        leaf_rotation=90,
        leaf_font_size=9,
        color_threshold=0  # puedes ajustar esto si quieres color automático
    )
    plt.title(f"Dendrograma (Ward linkage, PCA={n_dim}D)", fontsize=14)
    plt.xlabel("Autores")
    plt.ylabel("Distancia")
    plt.tight_layout()
    
    # Guardar cada dendrograma como imagen
    plt.savefig(f"Keywords/Hierarchical/dendrogram_pca_{n_dim}.png")
    plt.show()

# %%
## Visualización
X_2d = PCA(n_components=2).fit_transform(X_normalized)

for _, row in best_per_k.iterrows():
    labels = row["Labels"]
    coords_df = pd.DataFrame(X_2d, columns=["x", "y"])
    coords_df["author"] = df.index
    coords_df["cluster"] = labels

    plt.figure(figsize=(7, 6), dpi=100)
    sns.scatterplot(
        data=coords_df,
        x="x", y="y",
        hue="cluster",
        palette="tab10",
        s=80,
        edgecolor='k',
        alpha=0.9
    )

    for _, r in coords_df.iterrows():
        plt.text(r["x"], r["y"], r["author"], fontsize=8, alpha=0.7)

    plt.title(f"PCA={row['PCA_dims']} | k={row['k']} | Silh={row['Silhouette']:.2f}")
    plt.xticks([]); plt.yticks([])
    plt.legend(title="Cluster", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Guardamos los resultados

# %%
## Guardar resultados
cluster_records = []

for _, row in best_per_k.iterrows():
    labels = row["Labels"]
    k = row["k"]
    pca_dims = row["PCA_dims"]
    silhouette = row["Silhouette"]
    ch_score = row["Calinski-Harabasz"]
    db_score = row["Davies-Bouldin"]

    for author, cluster in zip(df.index, labels):
        cluster_records.append({
            "author": author,
            "cluster": int(cluster),
            "k": k,
            "pca_dims": pca_dims,
            "silhouette": silhouette,
            "calinski_harabasz": ch_score,
            "davies_bouldin": db_score
        })

df_clusters_export = pd.DataFrame(cluster_records)
df_clusters_export.to_csv("Keywords/Hierarchical/hierarchical_best_configs.csv", index=False)
print("✅ Resultados jerárquicos guardados en CSV.")
# Out:
# ✅ Resultados jerárquicos guardados en CSV.
