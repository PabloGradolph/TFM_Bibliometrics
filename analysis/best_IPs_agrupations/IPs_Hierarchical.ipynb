# %% [markdown]
# ## Agrupación de IPs por sus palabras clave

# %% [markdown]
# Paso 1: Cargar el dataset

# %%
import pandas as pd

df = pd.read_csv("Keywords/author_keyword_matrix.csv", index_col=0)

# Mostrar resumen
print("✅ Dataset generado con forma:", df.shape)
print("🔢 Palabras clave totales:", len(df.columns))
print("👥 Autores con keywords:", len(df))
# Out:
# ✅ Dataset generado con forma: (29, 3325)
# 🔢 Palabras clave totales: 3325
# 👥 Autores con keywords: 29

# %% [markdown]
# Paso 2: Preprocesamiento (normalización y reducción PCA)

# %%
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA

X = df.values
X_normalized = Normalizer().fit_transform(X)

# %% [markdown]
# Paso 3: Clustering con Jerárquico

# %%
# === Configuraciones de preprocesamiento y clustering ===
pca_dims = [2, 5, 10, 20]
k_values = list(range(2, 16))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# Evaluar KMeans para k entre 2 y 15
results = []

for n_dim in pca_dims:
    X_reduced = PCA(n_components=n_dim).fit_transform(X_normalized)

    Z = linkage(X_reduced, method='ward')

    for k in k_values:
        try:
            labels = fcluster(Z, t=k, criterion='maxclust')

            silhouette = silhouette_score(X_reduced, labels)
            ch_score = calinski_harabasz_score(X_reduced, labels)
            db_score = davies_bouldin_score(X_reduced, labels)

            results.append({
                "PCA_dims": n_dim,
                "k": k,
                "Silhouette": silhouette,
                "Calinski-Harabasz": ch_score,
                "Davies-Bouldin": db_score,
                "Labels": labels
            })

        except Exception as e:
            results.append({
                "PCA_dims": n_dim,
                "k": k,
                "Silhouette": np.nan,
                "Calinski-Harabasz": np.nan,
                "Davies-Bouldin": np.nan,
                "Error": str(e),
                "Labels": []
            })

df_results = pd.DataFrame(results).dropna(subset=["Silhouette"])
print("✅ Resultados de clustering jerárquico generados:", df_results.shape)
print("🔍 Resultados de clustering:", df_results)
# Out:
# ✅ Resultados de clustering jerárquico generados: (56, 6)
# 🔍 Resultados de clustering:     PCA_dims   k  Silhouette  Calinski-Harabasz  Davies-Bouldin  \
# 0          2   2    0.461144          24.528851        0.843788
# 1          2   3    0.587275          44.772754        0.592639
# 2          2   4    0.537077          46.979155        0.521313
# 3          2   5    0.573821          64.698316        0.580848
# 4          2   6    0.627780          79.487250        0.449195
# 5          2   7    0.662955          91.054724        0.445515
# 6          2   8    0.626503         100.547856        0.455541
# 7          2   9    0.677567         121.205617        0.338409
# 8          2  10    0.634496         130.273245        0.304786
# 9          2  11    0.631164         149.891101        0.329970
# 10         2  12    0.627584         180.159459        0.381513
# 11         2  13    0.608778         201.737437        0.318097
# 12         2  14    0.541973         237.046933        0.399154
# 13         2  15    0.529469         293.398063        0.325813
# 14         5   2    0.302763           8.243011        0.826952
# 15         5   3    0.372315           8.933783        0.909716
# 16         5   4    0.438212          11.005029        1.032847
# 17         5   5    0.508548          14.426956        0.821728
# 18         5   6    0.596830          22.252561        0.536799
# 19         5   7    0.674763          41.389704        0.407287
# 20         5   8    0.672177          50.264184        0.416219
# 21         5   9    0.729812          71.499859        0.353272
# 22         5  10    0.711107          82.722255        0.406291
# 23         5  11    0.651693          94.599424        0.389214
# 24         5  12    0.614039         111.643113        0.293726
# 25         5  13    0.596498         127.722365        0.196823
# 26         5  14    0.534650         154.539806        0.253590
# 27         5  15    0.524453         202.609328        0.291013
# 28        10   2    0.147826           4.758008        1.215259
# 29        10   3    0.214968           4.723720        1.664642
# 30        10   4    0.271136           5.158476        1.569587
# 31        10   5    0.343218           5.649236        1.328855
# 32        10   6    0.412701           6.346264        1.130125
# 33        10   7    0.495145           7.560127        0.964817
# 34        10   8    0.591483           9.777475        0.739797
# 35        10   9    0.629160          12.530087        0.746892
# 36        10  10    0.685545          18.523613        0.611066
# 37        10  11    0.743299          34.943949        0.402643
# 38        10  12    0.698264          39.746733        0.299320
# 39        10  13    0.689375          48.021430        0.306160
# 40        10  14    0.647302          53.844268        0.357163
# 41        10  15    0.625698          59.943237        0.321813
# 42        20   2    0.073055           3.096212        1.822020
# 43        20   3    0.106445           2.908798        2.267990
# 44        20   4    0.150890           2.961074        2.145940
# 45        20   5    0.209972           2.987002        1.879321
# 46        20   6    0.271287           3.071118        1.718128
# 47        20   7    0.327663           3.190666        1.499081
# 48        20   8    0.411751           3.357233        1.303436
# 49        20   9    0.426742           3.461224        1.308322
# 50        20  10    0.433220           3.531946        1.312700
# 51        20  11    0.434643           3.610009        1.256006
# 52        20  12    0.435486           3.742775        1.003123
# 53        20  13    0.437500           3.931504        0.904797
# 54        20  14    0.439532           4.231092        0.807303
# 55        20  15    0.440333           4.679509        0.684530
#
#                                                Labels
# 0   [2, 1, 1, 2, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 1, ...
# 1   [3, 1, 1, 3, 3, 1, 3, 2, 3, 3, 1, 2, 2, 1, 1, ...
# 2   [3, 1, 1, 4, 4, 1, 3, 2, 4, 4, 1, 2, 2, 1, 1, ...
# 3   [4, 2, 2, 5, 5, 2, 4, 3, 5, 5, 2, 3, 3, 1, 1, ...
# 4   [5, 2, 2, 6, 6, 3, 5, 4, 6, 6, 3, 4, 4, 1, 1, ...
# 5   [5, 2, 2, 7, 7, 3, 5, 4, 7, 7, 3, 4, 4, 1, 1, ...
# 6   [6, 2, 2, 8, 8, 3, 6, 5, 8, 8, 3, 4, 4, 1, 1, ...
# 7   [6, 2, 2, 9, 9, 3, 6, 5, 8, 8, 3, 4, 4, 1, 1, ...
# 8   [7, 2, 2, 10, 10, 3, 7, 6, 9, 9, 3, 5, 5, 1, 1...
# 9   [8, 3, 3, 11, 11, 4, 8, 7, 10, 10, 4, 6, 6, 1,...
# 10  [9, 3, 3, 12, 12, 4, 9, 7, 11, 11, 4, 6, 6, 1,...
# 11  [10, 3, 3, 13, 13, 4, 10, 8, 12, 12, 5, 7, 7, ...
# 12  [11, 3, 3, 14, 14, 4, 10, 8, 13, 13, 5, 7, 7, ...
# 13  [12, 3, 3, 15, 15, 4, 11, 8, 14, 14, 5, 7, 7, ...
# 14  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 15  [3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 1, 1, ...
# 16  [4, 4, 4, 2, 2, 4, 4, 3, 4, 4, 4, 3, 3, 1, 1, ...
# 17  [5, 4, 4, 2, 2, 5, 5, 3, 5, 5, 5, 3, 3, 1, 1, ...
# 18  [6, 5, 5, 2, 2, 6, 6, 4, 6, 6, 6, 3, 3, 1, 1, ...
# 19  [7, 5, 5, 2, 2, 7, 7, 4, 6, 6, 7, 3, 3, 1, 1, ...
# 20  [7, 5, 5, 2, 2, 8, 7, 4, 6, 6, 8, 3, 3, 1, 1, ...
# 21  [8, 6, 6, 3, 3, 9, 8, 5, 7, 7, 9, 4, 4, 1, 1, ...
# 22  [9, 7, 7, 3, 3, 10, 9, 6, 8, 8, 10, 4, 4, 1, 1...
# 23  [10, 8, 8, 4, 4, 11, 10, 7, 9, 9, 11, 5, 5, 1,...
# 24  [10, 8, 8, 4, 4, 11, 10, 7, 9, 9, 12, 5, 5, 1,...
# 25  [11, 9, 9, 4, 4, 12, 11, 7, 10, 10, 13, 5, 5, ...
# 26  [12, 9, 9, 4, 4, 13, 11, 7, 10, 10, 14, 5, 5, ...
# 27  [13, 10, 10, 5, 5, 14, 12, 8, 11, 11, 15, 6, 6...
# 28  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 29  [3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 2, 1, 1, ...
# 30  [4, 4, 4, 3, 3, 4, 4, 2, 4, 4, 4, 2, 2, 1, 1, ...
# 31  [5, 5, 5, 3, 3, 5, 5, 2, 4, 4, 5, 2, 2, 1, 1, ...
# 32  [6, 5, 5, 3, 3, 6, 6, 2, 4, 4, 6, 2, 2, 1, 1, ...
# 33  [7, 6, 6, 4, 4, 7, 7, 3, 5, 5, 7, 2, 2, 1, 1, ...
# 34  [8, 7, 7, 5, 5, 8, 8, 3, 6, 6, 8, 2, 2, 1, 1, ...
# 35  [9, 7, 7, 5, 5, 8, 8, 3, 6, 6, 8, 2, 2, 1, 1, ...
# 36  [10, 7, 7, 5, 5, 8, 8, 3, 6, 6, 8, 2, 2, 1, 1,...
# 37  [10, 7, 7, 5, 5, 8, 8, 3, 6, 6, 8, 2, 2, 1, 1,...
# 38  [11, 7, 7, 5, 5, 8, 9, 3, 6, 6, 8, 2, 2, 1, 1,...
# 39  [12, 8, 8, 6, 6, 9, 10, 4, 7, 7, 9, 3, 3, 1, 1...
# 40  [13, 9, 9, 7, 7, 10, 11, 5, 8, 8, 10, 3, 3, 1,...
# 41  [14, 9, 9, 7, 7, 10, 12, 5, 8, 8, 11, 3, 3, 1,...
# 42  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, ...
# 43  [3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 2, 1, 1, ...
# 44  [4, 4, 4, 3, 3, 4, 4, 2, 4, 4, 4, 2, 2, 1, 1, ...
# 45  [5, 4, 4, 3, 3, 5, 5, 2, 5, 5, 5, 2, 2, 1, 1, ...
# 46  [6, 4, 4, 3, 3, 6, 6, 2, 5, 5, 6, 2, 2, 1, 1, ...
# 47  [7, 5, 5, 4, 4, 7, 7, 3, 6, 6, 7, 2, 2, 1, 1, ...
# 48  [8, 6, 6, 5, 5, 8, 8, 3, 7, 7, 8, 2, 2, 1, 1, ...
# 49  [9, 6, 6, 5, 5, 8, 9, 3, 7, 7, 8, 2, 2, 1, 1, ...
# 50  [10, 6, 6, 5, 5, 8, 10, 3, 7, 7, 8, 2, 2, 1, 1...
# 51  [11, 6, 6, 5, 5, 8, 11, 3, 7, 7, 8, 2, 2, 1, 1...
# 52  [11, 6, 6, 5, 5, 8, 11, 3, 7, 7, 8, 2, 2, 1, 1...
# 53  [11, 6, 6, 5, 5, 8, 11, 3, 7, 7, 8, 2, 2, 1, 1...
# 54  [11, 6, 6, 5, 5, 8, 12, 3, 7, 7, 8, 2, 2, 1, 1...
# 55  [12, 6, 6, 5, 5, 8, 13, 3, 7, 7, 8, 2, 2, 1, 1...

# %%
## Selección por score combinado
from sklearn.preprocessing import MinMaxScaler

metrics = df_results[["Silhouette", "Calinski-Harabasz", "Davies-Bouldin"]].copy()
metrics["Davies-Bouldin"] = -metrics["Davies-Bouldin"]
scaled = pd.DataFrame(MinMaxScaler().fit_transform(metrics), columns=metrics.columns)

df_results["score_combined"] = (
    0.8 * scaled["Silhouette"] +
    0.1 * scaled["Calinski-Harabasz"] +
    0.1 * scaled["Davies-Bouldin"]
)

best_per_k = (
    df_results
    .sort_values("score_combined", ascending=False)
    .drop_duplicates(subset=["k"])
    .sort_values("k")
)

print("✅ Mejores configuraciones jerárquicas por número de clusters:")
print(best_per_k[["PCA_dims", "k", "Silhouette", "Calinski-Harabasz", "Davies-Bouldin", "score_combined"]])
# Out:
# ✅ Mejores configuraciones jerárquicas por número de clusters:
#     PCA_dims   k  Silhouette  Calinski-Harabasz  Davies-Bouldin  \
# 0          2   2    0.461144          24.528851        0.843788
# 1          2   3    0.587275          44.772754        0.592639
# 2          2   4    0.537077          46.979155        0.521313
# 3          2   5    0.573821          64.698316        0.580848
# 4          2   6    0.627780          79.487250        0.449195
# 5          2   7    0.662955          91.054724        0.445515
# 20         5   8    0.672177          50.264184        0.416219
# 21         5   9    0.729812          71.499859        0.353272
# 22         5  10    0.711107          82.722255        0.406291
# 37        10  11    0.743299          34.943949        0.402643
# 38        10  12    0.698264          39.746733        0.299320
# 39        10  13    0.689375          48.021430        0.306160
# 40        10  14    0.647302          53.844268        0.357163
# 41        10  15    0.625698          59.943237        0.321813
#
#     score_combined
# 0         0.539427
# 1         0.709072
# 2         0.653359
# 3         0.700441
# 4         0.776294
# 5         0.822438
# 20        0.820818
# 21        0.899960
# 22        0.878938
# 37        0.901091
# 38        0.853979
# 39        0.845887
# 40        0.795212
# 41        0.773231

# %% [markdown]
# Visualizamos las configuraciones

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# === Generar dendrogramas por cada configuración de PCA ===
pca_dims = [2, 5, 10, 20]
for n_dim in pca_dims:
    X_reduced = PCA(n_components=n_dim).fit_transform(X_normalized)
    
    # Linkage
    Z = linkage(X_reduced, method='ward')

    # Dendrograma
    plt.figure(figsize=(14, 6), dpi=100)
    dendrogram(
        Z,
        labels=df.index.tolist(),
        leaf_rotation=90,
        leaf_font_size=9,
        color_threshold=0  # puedes ajustar esto si quieres color automático
    )
    plt.title(f"Dendrograma (Ward linkage, PCA={n_dim}D)", fontsize=14)
    plt.xlabel("Autores")
    plt.ylabel("Distancia")
    plt.tight_layout()
    
    # Guardar cada dendrograma como imagen
    plt.savefig(f"Keywords/Hierarchical/dendrogram_pca_{n_dim}.png")
    plt.show()

# %%
## Visualización
X_2d = PCA(n_components=2).fit_transform(X_normalized)

for _, row in best_per_k.iterrows():
    labels = row["Labels"]
    coords_df = pd.DataFrame(X_2d, columns=["x", "y"])
    coords_df["author"] = df.index
    coords_df["cluster"] = labels

    plt.figure(figsize=(7, 6), dpi=100)
    sns.scatterplot(
        data=coords_df,
        x="x", y="y",
        hue="cluster",
        palette="tab10",
        s=80,
        edgecolor='k',
        alpha=0.9
    )

    for _, r in coords_df.iterrows():
        plt.text(r["x"], r["y"], r["author"], fontsize=8, alpha=0.7)

    plt.title(f"PCA={row['PCA_dims']} | k={row['k']} | Silh={row['Silhouette']:.2f}")
    plt.xticks([]); plt.yticks([])
    plt.legend(title="Cluster", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Guardamos los resultados

# %%
## Guardar resultados
cluster_records = []

for _, row in best_per_k.iterrows():
    labels = row["Labels"]
    k = row["k"]
    pca_dims = row["PCA_dims"]
    silhouette = row["Silhouette"]
    ch_score = row["Calinski-Harabasz"]
    db_score = row["Davies-Bouldin"]

    for author, cluster in zip(df.index, labels):
        cluster_records.append({
            "author": author,
            "cluster": int(cluster),
            "k": k,
            "pca_dims": pca_dims,
            "silhouette": silhouette,
            "calinski_harabasz": ch_score,
            "davies_bouldin": db_score
        })

df_clusters_export = pd.DataFrame(cluster_records)
df_clusters_export.to_csv("Keywords/Hierarchical/hierarchical_best_configs.csv", index=False)
print("✅ Resultados jerárquicos guardados en CSV.")
# Out:
# ✅ Resultados jerárquicos guardados en CSV.
